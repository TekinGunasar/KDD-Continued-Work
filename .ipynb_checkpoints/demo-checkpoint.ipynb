# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Extracting data from downloaded files

# %%
from src.data_wrangling import *
import matplotlib.pyplot as plt

# %%
data_dir = 'CLA Datasets'
save_as = 'dataset_CLA_nonaugmented.pkl'

create_dataset(data_dir,save_as)
# Out:
# Reading CLA Datasets\CLA-SubjectJ-170504-3St-LRHand-Inter.mat
#
# Reading CLA Datasets\CLA-SubjectJ-170508-3St-LRHand-Inter.mat
#
# Error Reading CLA Datasets\CLA-SubjectJ-170508-3St-LRHand-Inter.mat
#
# Reading CLA Datasets\CLA-SubjectJ-170510-3St-LRHand-Inter.mat
#
# Error Reading CLA Datasets\CLA-SubjectJ-170510-3St-LRHand-Inter.mat
#
# Reading CLA Datasets\CLASubjectA1601083StLRHand.mat
#
# Reading CLA Datasets\CLASubjectB1510193StLRHand.mat
#
# Reading CLA Datasets\CLASubjectB1510203StLRHand.mat
#
# Reading CLA Datasets\CLASubjectB1512153StLRHand.mat
#
# Reading CLA Datasets\CLASubjectC1511263StLRHand.mat
#
# Reading CLA Datasets\CLASubjectC1512163StLRHand.mat
#
# Reading CLA Datasets\CLASubjectC1512233StLRHand.mat
#
# Reading CLA Datasets\CLASubjectD1511253StLRHand.mat
#
# Reading CLA Datasets\CLASubjectE1512253StLRHand.mat
#
# Reading CLA Datasets\CLASubjectE1601193StLRHand.mat
#
# Reading CLA Datasets\CLASubjectE1601223StLRHand.mat
#
# Reading CLA Datasets\CLASubjectF1509163StLRHand.mat
#
# Reading CLA Datasets\CLASubjectF1509173StLRHand.mat
#
# Reading CLA Datasets\CLASubjectF1509283StLRHand.mat
#
# Train trials length: 6927,Train labels length: 6927
# Validation trials length: 1979,Validation labels length: 1979
# Testing trials length: 991,Testing labels length: 991

# %% [markdown]
# ### Technical Validation

# %% [markdown]
# Plotting left and right hand motor imagery for one of the subjects shown in the study and making sure that ERP curve has same form. Instructions for how these plots were generated on page 9 of Kaya et al.
#
# Only testing one one, getting from signal onset to 1.5 seconds after.

# %%
from src.data_wrangling import *
from src.dataset_wrappers import *
from src.preprocessing import *

# %%
#SubjectE-151225
trials_val,labels_val = technical_validation_dataset = load_dataset('Technical Validation Data.pkl')

# %%
marker_dict = {
    1:'left',
    2:'right'
}

#Organizing the whole list of signals into left and right into each entry of the dictionary, and then also a seperate dict for ERP curve we plot after
group_dict,averaged_group_dict = organize_into_groups(marker_dict,trials_val,labels_val,average_signals=True)

# %%
subject_name = 'CLA-SubjectE-151225'

t = np.linspace(start=0,stop=1500,num=300)
plt.plot(t,averaged_group_dict['right'][0],color='red')
plt.plot(t,averaged_group_dict['left'][0],color='blue')

plt.xlabel('Time since onset (ms)')
plt.ylabel('Electric Potential(mu v)')

plt.legend(['Right','Left'])

plt.title(subject_name);

# %% [markdown]
# Done from signal onset to 1.5 seconds after. Range is +/- 3 microvolts for channel C3, as mentioned by study. Can compare the above figure with the figure on page 9 for mentiond subject directly.

# %% [markdown]
# General form matches for the above subject. Data parsing seems to have been done correctly.

# %% [markdown]
# ### Power Spectrum for above ERP Curve

# %%
from scipy.signal import periodogram

# %%
#Just doing C3 for technical validation to compare with Kaya et. al
psd_right = periodogram(averaged_group_dict['right'][0],fs=200)
psd_left = periodogram(averaged_group_dict['left'][0],fs=200)

# %%
data_indices = psd_right[0]

mu_start = np.argmax(data_indices >= 8)
mu_end = np.argmax(data_indices >= 13)

relevant_indices = data_indices[mu_start:mu_end]

relevant_data_right = psd_right[1][mu_start:mu_end]
relevant_data_left = psd_left[1][mu_start:mu_end]

# %%
plt.plot(relevant_indices,relevant_data_right,color='red');
plt.plot(relevant_indices,relevant_data_left,color='blue');

plt.legend(['Right','Left']);

# %% [markdown]
# ### Auto-Encoder Pre-Training

# %%
from src.models.CAE import ConvolutionalAutoEncoder
import tensorflow as tf
import os

import matplotlib.pyplot as plt
import numpy as np

from src.dataset_wrappers import *
from sklearn.decomposition import PCA

# %%
dataset_path = 'dataset_CLA_nonaugmented.pkl'
training_settings_json = 'TRAINING_SETTINGS/auto_encoder_pre_training/test.json'

CAE = ConvolutionalAutoEncoder(dataset_path,training_settings_json)
CAE.build_encoder()
CAE.build_decoder()
CAE.build_auto_encoder()

optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.MeanSquaredError()

CAE.compile_auto_encoder(loss,optimizer)

experiment_dir = 'Experiments/Simplest Model with accuracy'

CAE.train(save_experiment=True,experiment_dir = experiment_dir,model_name = 'auto_encoder.keras')
# Out:
# Training steps per epoch: ~55
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.959338903427124
# Training loss: 0.9595537781715393
#
# Validation accuracy: 0.32036382011116726
# Training accuracy: 0.2797747942832395
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.7063062787055969
# Training loss: 0.7018230557441711
#
# Validation accuracy: 0.20768064679130874
# Training accuracy: 0.20124151869496174
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.6215295791625977
# Training loss: 0.6158924102783203
#
# Validation accuracy: 0.2753916119252148
# Training accuracy: 0.20412877147394254
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.5426806211471558
# Training loss: 0.537343442440033
#
# Validation accuracy: 0.20515411824153612
# Training accuracy: 0.32048505846686876
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.49434927105903625
# Training loss: 0.4894329905509949
#
# Validation accuracy: 0.27286508337544213
# Training accuracy: 0.2929117944276021
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.461225688457489
# Training loss: 0.45623478293418884
#
# Validation accuracy: 0.28802425467407783
# Training accuracy: 0.1960444636927963
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.4379599988460541
# Training loss: 0.43328630924224854
#
# Validation accuracy: 0.20970186963112683
# Training accuracy: 0.29435542081709254
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.4216457009315491
# Training loss: 0.4165811240673065
#
# Validation accuracy: 0.28196058615462355
# Training accuracy: 0.19214667244117223
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.4069260358810425
# Training loss: 0.4027072787284851
#
# Validation accuracy: 0.19858514401212735
# Training accuracy: 0.19214667244117223
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.39491620659828186
# Training loss: 0.38969686627388
#
# Validation accuracy: 0.18089944416371906
# Training accuracy: 0.1869496174390068
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3836726248264313
# Training loss: 0.3786891996860504
#
# Validation accuracy: 0.18140474987367358
# Training accuracy: 0.30373899234878016
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.374645859003067
# Training loss: 0.3690004348754883
#
# Validation accuracy: 0.3168266801414856
# Training accuracy: 0.2994081131803089
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3670242130756378
# Training loss: 0.3615058958530426
#
# Validation accuracy: 0.3218797372410308
# Training accuracy: 0.27342283816948176
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.35814544558525085
# Training loss: 0.35252586007118225
#
# Validation accuracy: 0.2784234461849419
# Training accuracy: 0.23661036523747653
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3511020541191101
# Training loss: 0.3451719284057617
#
# Validation accuracy: 0.21829206670035373
# Training accuracy: 0.24469467301862277
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.344887375831604
# Training loss: 0.3392445743083954
#
# Validation accuracy: 0.22587165234967155
# Training accuracy: 0.2338674750974448
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3375528156757355
# Training loss: 0.33185875415802
#
# Validation accuracy: 0.2516422435573522
# Training accuracy: 0.23487801357008806
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.33067378401756287
# Training loss: 0.32435110211372375
#
# Validation accuracy: 0.24962102071753411
# Training accuracy: 0.23112458495741303
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.32095304131507874
# Training loss: 0.3157612383365631
#
# Validation accuracy: 0.2425467407781708
# Training accuracy: 0.22765988162263606
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.31258681416511536
# Training loss: 0.30765843391418457
#
# Validation accuracy: 0.2177867609903992
# Training accuracy: 0.26837014580626534
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.30564868450164795
# Training loss: 0.30069226026535034
#
# Validation accuracy: 0.20060636685194544
# Training accuracy: 0.27428901400317596
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3003433346748352
# Training loss: 0.2952266335487366
#
# Validation accuracy: 0.2026275896917635
# Training accuracy: 0.2770319041432077
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.29337751865386963
# Training loss: 0.2892213463783264
#
# Validation accuracy: 0.19807983830217282
# Training accuracy: 0.21611087050671288
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.28867968916893005
# Training loss: 0.2849327027797699
#
# Validation accuracy: 0.20414350682162707
# Training accuracy: 0.27241229969683844
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.2851724922657013
# Training loss: 0.28134170174598694
#
# Validation accuracy: 0.2945932289034866
# Training accuracy: 0.22405081564891005
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.2816649377346039
# Training loss: 0.27782100439071655
#
# Validation accuracy: 0.30015159171298633
# Training accuracy: 0.2162552331456619
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.27873361110687256
# Training loss: 0.27503564953804016
#
# Validation accuracy: 0.31126831733198584
# Training accuracy: 0.27789807997690197
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.27763116359710693
# Training loss: 0.2728673219680786
#
# Validation accuracy: 0.16270843860535625
# Training accuracy: 0.21538905731196767
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.27273809909820557
# Training loss: 0.2688864469528198
#
# Validation accuracy: 0.16472966144517434
# Training accuracy: 0.21250180453298687
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.27277255058288574
# Training loss: 0.2679102420806885
#
# Validation accuracy: 0.32693279434057604
# Training accuracy: 0.21668832106250902
#
# Adding test loss and test accuracy to training history...
# Test loss is 0.29049035906791687
# Test accuracy is 0.3007063572149344

# %%
CAE.show_random_reconstruction()

# %% [markdown]
# ### DEC Training

# %%
from src.models.DEC import DeepEmbeddedClustering

# %%
DEC_TRAINING_SETTINGS_JSON = 'TRAINING_SETTINGS/dec_training/test.json'
experiment_dir = 'Experiments/Simplest Model with accuracy'

DEC = DeepEmbeddedClustering(dataset_path,DEC_TRAINING_SETTINGS_JSON,experiment_dir)

# %%
DEC.load_auto_encoder()
DEC.extract_encoder()

# %%
initial_embeddings = DEC.get_embeddings(DEC.training_trials)
DEC.initialize_cluster_centers(initial_embeddings)
# Out:
# C:\Users\20gun\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
loss = tf.keras.losses.KLDivergence()
optimizer = tf.keras.optimizers.SGD()

DEC.compile_encoder(loss,optimizer)

# %%
DEC.train()
# Out:
# Initial training accuracy (by soft assignments): 0.4772956609485368
# Initial validation accuracy (by soft assignments): 0.4593228903486609
#
# Training steps per epoch: ~55
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.006714217364788055
# Validation loss: 0.006534523330628872
#
# Training accuracy (by soft assignments): 0.47527749747729564
# Validation accuracy (by soft assignments): 0.4578069732187974
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.007347727194428444
# Validation loss: 0.007149546407163143
#
# Training accuracy (by soft assignments): 0.47426841574167505
# Validation accuracy (by soft assignments): 0.4573016675088428
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.008023036643862724
# Validation loss: 0.007804983761161566
#
# Training accuracy (by soft assignments): 0.47527749747729564
# Validation accuracy (by soft assignments): 0.45831227892875187
#   0%|          | 0/55 [00:00<?, ? batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 DEC.train()
#
# File ~\OneDrive\Desktop\KDD Continued\src\models\DEC.py:240, in DeepEmbeddedClustering.train(self, save_experiment, model_name)
#     237 epoch_progress.set_description(desc=f'Epoch {epoch + 1} / {num_epochs}')
#     239 for step,(x_batch_train,y_batch_train) in enumerate(train_trials_as_tf_dataset):
# --> 240     self.train_step(x_batch_train,y_batch_train)
#     241     epoch_progress.update(1)
#     244 validation_loss = self.evaluate_validation_loss()
#
# File ~\OneDrive\Desktop\KDD Continued\src\models\DEC.py:204, in DeepEmbeddedClustering.train_step(self, x_batch_train, y_batch_train)
#     200     target_distribution = self.target_distribution(soft_assignments)
#     202     loss = self.loss(soft_assignments,target_distribution)
# --> 204 grad_encoder_params = tape.gradient(loss,self.encoder.trainable_weights)
#     205 grad_cluster_centers = tape.gradient(loss,self.cluster_centers)
#     207 self.optimizer.apply_gradients(zip(grad_encoder_params,self.encoder.trainable_weights))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\backprop.py:1063, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1057   output_gradients = (
#    1058       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1059           output_gradients))
#    1060   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1061                       for x in output_gradients]
# -> 1063 flat_grad = imperative_grad.imperative_grad(
#    1064     self._tape,
#    1065     flat_targets,
#    1066     flat_sources,
#    1067     output_gradients=output_gradients,
#    1068     sources_raw=flat_sources_raw,
#    1069     unconnected_gradients=unconnected_gradients)
#    1071 if not self._persistent:
#    1072   # Keep track of watched variables before setting tape to None
#    1073   self._watched_variables = self._tape.watched_variables()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:789, in _TapeGradientFunctions._wrap_backward_function.<locals>._backward_function_wrapper(*args)
#     787   if input_index >= backward_function_inputs:
#     788     break
# --> 789 return backward._call_flat(  # pylint: disable=protected-access
#     790     processed_args, remapped_captures)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
training_embeddings = DEC.get_embeddings(DEC.training_trials)

# %%
plt.scatter(training_embeddings[:,0],training_embeddings[:,8])
plt.scatter(DEC.cluster_centers[0][0],DEC.cluster_centers[0][1],alpha=0.5)
plt.scatter(DEC.cluster_centers[1][8],DEC.cluster_centers[1][8],alpha=0.5)

# %%
DEC.cluster_centers[0]
