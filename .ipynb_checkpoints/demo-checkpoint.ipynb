# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Extracting data from downloaded files

# %%
from src.data_wrangling import *
import matplotlib.pyplot as plt

# %%
data_dir = 'CLA Datasets'
save_as = 'dataset_CLA_nonaugmented.pkl'

create_dataset(data_dir,save_as)
# Out:
# Reading CLA Datasets\CLA-SubjectJ-170504-3St-LRHand-Inter.mat
#
# Reading CLA Datasets\CLA-SubjectJ-170508-3St-LRHand-Inter.mat
#
# Error Reading CLA Datasets\CLA-SubjectJ-170508-3St-LRHand-Inter.mat
#
# Reading CLA Datasets\CLA-SubjectJ-170510-3St-LRHand-Inter.mat
#
# Error Reading CLA Datasets\CLA-SubjectJ-170510-3St-LRHand-Inter.mat
#
# Reading CLA Datasets\CLASubjectA1601083StLRHand.mat
#
# Reading CLA Datasets\CLASubjectB1510193StLRHand.mat
#
# Reading CLA Datasets\CLASubjectB1510203StLRHand.mat
#
# Reading CLA Datasets\CLASubjectB1512153StLRHand.mat
#
# Reading CLA Datasets\CLASubjectC1511263StLRHand.mat
#
# Reading CLA Datasets\CLASubjectC1512163StLRHand.mat
#
# Reading CLA Datasets\CLASubjectC1512233StLRHand.mat
#
# Reading CLA Datasets\CLASubjectD1511253StLRHand.mat
#
# Reading CLA Datasets\CLASubjectE1512253StLRHand.mat
#
# Reading CLA Datasets\CLASubjectE1601193StLRHand.mat
#
# Reading CLA Datasets\CLASubjectE1601223StLRHand.mat
#
# Reading CLA Datasets\CLASubjectF1509163StLRHand.mat
#
# Reading CLA Datasets\CLASubjectF1509173StLRHand.mat
#
# Reading CLA Datasets\CLASubjectF1509283StLRHand.mat
#
# Train trials length: 6927,Train labels length: 6927
# Validation trials length: 1979,Validation labels length: 1979
# Testing trials length: 991,Testing labels length: 991

# %% [markdown]
# ### Technical Validation

# %% [markdown]
# Plotting left and right hand motor imagery for one of the subjects shown in the study and making sure that ERP curve has same form. Instructions for how these plots were generated on page 9 of Kaya et al.
#
# Only testing one one, getting from signal onset to 1.5 seconds after.

# %%
from src.data_wrangling import *
from src.dataset_wrappers import *
from src.preprocessing import *

# %%
#SubjectE-151225
trials_val,labels_val = technical_validation_dataset = load_dataset('Technical Validation Data.pkl')

# %%
marker_dict = {
    1:'left',
    2:'right'
}

#Organizing the whole list of signals into left and right into each entry of the dictionary, and then also a seperate dict for ERP curve we plot after
group_dict,averaged_group_dict = organize_into_groups(marker_dict,trials_val,labels_val,average_signals=True)

# %%
subject_name = 'CLA-SubjectE-151225'

t = np.linspace(start=0,stop=1500,num=300)
plt.plot(t,averaged_group_dict['right'][0],color='red')
plt.plot(t,averaged_group_dict['left'][0],color='blue')

plt.xlabel('Time since onset (ms)')
plt.ylabel('Electric Potential(mu v)')

plt.legend(['Right','Left'])

plt.title(subject_name);

# %% [markdown]
# Done from signal onset to 1.5 seconds after. Range is +/- 3 microvolts for channel C3, as mentioned by study. Can compare the above figure with the figure on page 9 for mentiond subject directly.

# %% [markdown]
# General form matches for the above subject. Data parsing seems to have been done correctly.

# %% [markdown]
# ### Power Spectrum for above ERP Curve

# %%
from scipy.signal import periodogram

# %%
#Just doing C3 for technical validation to compare with Kaya et. al
psd_right = periodogram(averaged_group_dict['right'][0],fs=200)
psd_left = periodogram(averaged_group_dict['left'][0],fs=200)

# %%
data_indices = psd_right[0]

mu_start = np.argmax(data_indices >= 8)
mu_end = np.argmax(data_indices >= 13)

relevant_indices = data_indices[mu_start:mu_end]

relevant_data_right = psd_right[1][mu_start:mu_end]
relevant_data_left = psd_left[1][mu_start:mu_end]

# %%
plt.plot(relevant_indices,relevant_data_right,color='red');
plt.plot(relevant_indices,relevant_data_left,color='blue');

plt.legend(['Right','Left']);

# %% [markdown]
# ### Auto-Encoder Pre-Training

# %%
from src.models.CAE import ConvolutionalAutoEncoder
import tensorflow as tf
import os

import matplotlib.pyplot as plt
import numpy as np

from src.dataset_wrappers import *
from sklearn.decomposition import PCA

# %%
dataset_path = 'dataset_CLA_nonaugmented.pkl'
training_settings_json = 'TRAINING_SETTINGS/auto_encoder_pre_training/test.json'

# %%
CAE = ConvolutionalAutoEncoder(dataset_path,training_settings_json)
CAE.build_encoder()
CAE.build_decoder()
CAE.build_auto_encoder()

optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.MeanSquaredError()

CAE.compile_auto_encoder(loss,optimizer)

experiment_dir = 'Experiments/Testing Experiments'

CAE.train(save_experiment=True,experiment_dir = experiment_dir,model_name = 'auto_encoder.keras')
# Out:
# Training steps per epoch: ~55
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.976822555065155
# Training loss: 0.9755319356918335
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.7362462282180786
# Training loss: 0.7317368984222412
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.6444474458694458
# Training loss: 0.6380153298377991
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.5719301104545593
# Training loss: 0.5667614340782166
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.504362165927887
# Training loss: 0.5014691352844238
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.4662657380104065
# Training loss: 0.4633408486843109
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.4399715065956116
# Training loss: 0.4373311698436737
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.4208419620990753
# Training loss: 0.418084979057312
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.40570324659347534
# Training loss: 0.4028359055519104
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.39211761951446533
# Training loss: 0.38866865634918213
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3811642825603485
# Training loss: 0.377079576253891
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.37367483973503113
# Training loss: 0.3681861162185669
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3611462116241455
# Training loss: 0.3567064106464386
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3539031744003296
# Training loss: 0.3492077887058258
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3478268086910248
# Training loss: 0.34221115708351135
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.33918750286102295
# Training loss: 0.33384445309638977
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3310748338699341
# Training loss: 0.32650068402290344
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.32421886920928955
# Training loss: 0.3206506371498108
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3168129324913025
# Training loss: 0.3126671612262726
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3132607936859131
# Training loss: 0.31067004799842834
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3053596317768097
# Training loss: 0.30154845118522644
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.3026030659675598
# Training loss: 0.2978699207305908
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.2968985438346863
# Training loss: 0.292570024728775
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.292196661233902
# Training loss: 0.28864356875419617
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.28880923986434937
# Training loss: 0.28485336899757385
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.28499355912208557
# Training loss: 0.2811695635318756
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.2853960692882538
# Training loss: 0.2804383337497711
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.18231050670146942
# Training loss: 0.18110352754592896
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.18020975589752197
# Training loss: 0.17903921008110046
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.17872583866119385
# Training loss: 0.17730651795864105
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.1772492527961731
# Training loss: 0.17571784555912018
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.17582793533802032
# Training loss: 0.1747485250234604
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.1745644211769104
# Training loss: 0.17369411885738373
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.17345663905143738
# Training loss: 0.17214104533195496
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.1729556769132614
# Training loss: 0.1714811623096466
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.17132169008255005
# Training loss: 0.1702147275209427
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.17049507796764374
# Training loss: 0.16932405531406403
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.16951975226402283
# Training loss: 0.16925311088562012
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.16859352588653564
# Training loss: 0.16760407388210297
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.1677931249141693
# Training loss: 0.16684795916080475
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Validation loss: 0.16673392057418823
# Training loss: 0.16587133705615997
#
# Adding test loss to training history...
# Test loss is 0.18425679206848145

# %%
CAE.show_random_reconstruction()

# %% [markdown]
# ### DEC Training

# %%
from src.models.DEC import DeepEmbeddedClustering

# %%
DEC_TRAINING_SETTINGS_JSON = 'TRAINING_SETTINGS/dec_training/test.json'
experiment_dir = 'Experiments/Testing Experiments'

DEC = DeepEmbeddedClustering(dataset_path,DEC_TRAINING_SETTINGS_JSON,experiment_dir)

# %%
DEC.load_auto_encoder()
DEC.extract_encoder()

# %%
initial_embeddings = DEC.get_embeddings(DEC.training_trials)
DEC.initialize_cluster_centers(initial_embeddings)
# Out:
# C:\Users\20gun\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
loss = tf.keras.losses.KLDivergence()
optimizer = tf.keras.optimizers.RMSprop()

DEC.compile_encoder(loss,optimizer)

# %%
DEC.train()
# Out:
# Training steps per epoch: ~55
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0016642098780721426
# Validation loss: 0.0016319274436682463
#
# Training accuracy: 0.6595928973581637
# Validation accuracy: 0.6659929257200606
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0015857545658946037
# Validation loss: 0.001553718582727015
#
# Training accuracy: 0.6584379962465714
# Validation accuracy: 0.6639717028802425
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0015105671482160687
# Validation loss: 0.001478951540775597
#
# Training accuracy: 0.6578605456907752
# Validation accuracy: 0.6629610914603336
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.001437941798940301
# Validation loss: 0.0014068299205973744
#
# Training accuracy: 0.6561281940233867
# Validation accuracy: 0.6609398686205155
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0013680527918040752
# Validation loss: 0.0013375550042837858
#
# Training accuracy: 0.6542514797170492
# Validation accuracy: 0.6609398686205155
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.001300455187447369
# Validation loss: 0.0012707189889624715
#
# Training accuracy: 0.6536740291612531
# Validation accuracy: 0.6563921172309247
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.001235407660715282
# Validation loss: 0.0012065417831763625
#
# Training accuracy: 0.6507867763822722
# Validation accuracy: 0.6563921172309247
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0011730112601071596
# Validation loss: 0.0011451547034084797
#
# Training accuracy: 0.6502093258264761
# Validation accuracy: 0.6538655886811521
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0011128935730084777
# Validation loss: 0.0010861136252060533
#
# Training accuracy: 0.6484769741590877
# Validation accuracy: 0.6533602829711975
#   0%|          | 0/55 [00:00<?, ? batch/s]
# Training loss: 0.0010549942962825298
# Validation loss: 0.001029307721182704
#
# Training accuracy: 0.6474664356864444
# Validation accuracy: 0.6513390601313794
